# %% [markdown]
# If we take 47, reverse and add, 47 + 74 = 121, which is palindromic.
#
# Not all numbers produce palindromes so quickly. For example,
#
# 349 + 943 = 1292,
# 1292 + 2921 = 4213
# 4213 + 3124 = 7337
#
# That is, 349 took three iterations to arrive at a palindrome.
#
# Although no one has proved it yet, it is thought that some numbers, like 196, never produce a palindrome. A number that never forms a palindrome through the reverse and add process is called a Lychrel number. Due to the theoretical nature of these numbers, and for the purpose of this problem, we shall assume that a number is Lychrel until proven otherwise. In addition you are given that for every number below ten-thousand, it will either (i) become a palindrome in less than fifty iterations, or, (ii) no one, with all the computing power that exists, has managed so far to map it to a palindrome. In fact, 10677 is the first number to be shown to require over fifty iterations before producing a palindrome: 4668731596684224866951378664 (53 iterations, 28-digits).
#
# Surprisingly, there are palindromic numbers that are themselves Lychrel numbers; the first example is 4994.
#
# How many Lychrel numbers are there below ten-thousand?
#
# NOTE: Wording was modified slightly on 24 April 2007 to emphasise the theoretical nature of Lychrel numbers.

# %%
#Find all Lychrel numbers below 10000

n=10    #Starting point
count=0 #Number of Lychrel numbers

for n in range(1,10001):
    a=n
    sa=str(a)
    sb=sa[::-1]
    b=int(sb)
    #We need fifty iterations
    for i in range(0,50): #Set to 50
        c=a+b
        sc=str(c)
        length=len(sc)
        #If the number is odd, we can erase the middle digit
        mid = length//2
        if(length%2==0):
            LEFT=sc[mid:]
            RIGHT=sc[:mid]
        else:
            LEFT=sc[(mid+1):]
            RIGHT=sc[:mid]
    
        RIGHT=RIGHT[::-1]   #Reverse RIGHT
    
        if(LEFT==RIGHT):    #Compare LEFT and RIGHT
            count=count+1
            break
        if(i==49):
            print("Lychrel:", n)
            break
        a=c
        sa=str(a)
        sb=sa[::-1]
        b=int(sb)
print("Total of Lychrel numbers:", 10000-count)
# Out:
# Lychrel: 196
# Lychrel: 295
# Lychrel: 394
# Lychrel: 493
# Lychrel: 592
# Lychrel: 689
# Lychrel: 691
# Lychrel: 788
# Lychrel: 790
# Lychrel: 879
# Lychrel: 887
# Lychrel: 978
# Lychrel: 986
# Lychrel: 1495
# Lychrel: 1497
# Lychrel: 1585
# Lychrel: 1587
# Lychrel: 1675
# Lychrel: 1677
# Lychrel: 1765
# Lychrel: 1767
# Lychrel: 1855
# Lychrel: 1857
# Lychrel: 1945
# Lychrel: 1947
# Lychrel: 1997
# Lychrel: 2494
# Lychrel: 2496
# Lychrel: 2584
# Lychrel: 2586
# Lychrel: 2674
# Lychrel: 2676
# Lychrel: 2764
# Lychrel: 2766
# Lychrel: 2854
# Lychrel: 2856
# Lychrel: 2944
# Lychrel: 2946
# Lychrel: 2996
# Lychrel: 3493
# Lychrel: 3495
# Lychrel: 3583
# Lychrel: 3585
# Lychrel: 3673
# Lychrel: 3675
# Lychrel: 3763
# Lychrel: 3765
# Lychrel: 3853
# Lychrel: 3855
# Lychrel: 3943
# Lychrel: 3945
# Lychrel: 3995
# Lychrel: 4079
# Lychrel: 4169
# Lychrel: 4259
# Lychrel: 4349
# Lychrel: 4439
# Lychrel: 4492
# Lychrel: 4494
# Lychrel: 4529
# Lychrel: 4582
# Lychrel: 4584
# Lychrel: 4619
# ...
