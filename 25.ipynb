# %% [markdown]
# The Fibonacci sequence is defined by the recurrence relation:
#
#     Fn = Fn−1 + Fn−2, where F1 = 1 and F2 = 1.
#
# Hence the first 12 terms will be:
#
#     F1 = 1
#     F2 = 1
#     F3 = 2
#     F4 = 3
#     F5 = 5
#     F6 = 8
#     F7 = 13
#     F8 = 21
#     F9 = 34
#     F10 = 55
#     F11 = 89
#     F12 = 144
#
# The 12th term, F12, is the first term to contain three digits.
#
# What is the index of the first term in the Fibonacci sequence to contain 1000 digits?

# %%
GOAL = 1000

i=1
j=1
a=1
suma=0
length=0
print(i)
while (length<GOAL):
    i=i+j
    j=i+j
    
    if(i%2==0):
        suma=i+suma
    if(j%2==0):
        suma=j+suma
    length=len(str(i))
    a=a+2
#Necesitamos conocer el index
print("La solución es:",a, i, j)
# Out:
# 1
# La solución es: 4783 ... ...

# %%
i=1
j=1
a=1
suma=0
length=0
print(i)
while (a<12):
    i=i+j
    j=i+j
    
    if(i%2==0):
        suma=i+suma
    if(j%2==0):
        suma=j+suma
    length=len(str(i))
    a=a+2
#Necesitamos conocer el index
print("La solución es:",a, i, j)
# Out:
# 1
# La solución es: 13 233 377

# %%
len(str(...))
# Out:
# 1000

# %%
len(str(...))
# Out:
# 999
